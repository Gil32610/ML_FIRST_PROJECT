# %%
print("hello, world!")
# Out:
# hello, world!

# %%
import os 
import tarfile
from six.moves import urllib

DOWNLOAD_ROOT = "https://raw.githubusercontent.com/ageron/handson-ml/master/"
HOUSING_PATH = os.path.join("datasets", "housing")
HOUSING_URL = DOWNLOAD_ROOT + "datasets/housing/housing.tgz"

def fetch_housing_data(housing_url=HOUSING_URL, housing_path=HOUSING_PATH):
    if not os.path.isdir(housing_path):
        os.makedirs(housing_path)
    tgz_path = os.path.join(housing_path, "housing.tgz")
    
    urllib.request.urlretrieve(housing_url, tgz_path)
    housing_tgz = tarfile.open(tgz_path)
    housing_tgz.extractall(path=housing_path)
    housing_tgz.close()

# %%
fetch_housing_data()

# %%
import pandas as pd

def load_housing_data(housing_path=HOUSING_PATH):
    csv_path = os.path.join(housing_path,"housing.csv")
    return pd.read_csv(csv_path)

# %%
housing = load_housing_data()
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
housing["ocean_proximity"].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: count, dtype: int64

# %%
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
housing.hist(bins=50, figsize=(35,30))
plt.show()

# %%
#Separação de Conjunto de Testes Nº 1
import numpy as np

def split_train_test(data, test_ratio):
    #permutação aleatória dos indices de acordo com o tamanho do conjunto
    shuffled_indices = np.random.permutation(len(data))
    #definindo tamanho do conjunto de testes a partir da proporção dada
    test_set_size = int(len(data)*test_ratio)

    #conjunto de testes começa no primeiro indice e vai até test_set_size
    test_indices = shuffled_indices[:test_set_size]

    #conjunto de treinamento começa a partir de test_set_size até o final do vetor
    train_indices = shuffled_indices[test_set_size:]

    #iloc: indexação por inteiros(ex:. 0, 1, 2...)
    return data.iloc[train_indices], data.iloc[test_indices]

# %%
train_set, test_set = split_train_test(housing, 0.2)
print(len(train_set), "train + ", len(test_set), "test")
# Out:
# 16512 train +  4128 test

# %%
#Separação de Conjunto de Testes Nº 2
import hashlib

def test_set_check(identifier, test_ratio, hash):
    #Mantendo apenas o último byte do hash gerado
    #Verificando se é menor que uma fração do conjunto total 
    return hash(np.int64(identifier)).digest()[-1]<256 * test_ratio
    #O indice [-1] retorna o último elemento de um tipo de dado

def split_train_test_by_id(data, test_ratio, id_column, hash=hashlib.md5):
    ids = data[id_column]

    #apply retorna um dataframe com uma função (lambda) aplicada em um eixo específico.
    in_test_set = ids.apply(lambda id_: test_set_check(id_, test_ratio, hash))

    #indexação por label 
    return data.loc[~in_test_set], data.loc[in_test_set]

# %%
#reinicia os indices de 0, 1, 2,..., n e mantém o indice "antigo"
#se drop=true, remove o indice anteriormente utilizado
housing_with_id = housing.reset_index()
train_set, test_set = split_train_test_by_id(housing_with_id, 0.2, "index")

# %%
train_set.head()
# Out:
#    index  longitude  latitude  housing_median_age  total_rooms  \
# 0      0    -122.23     37.88                41.0        880.0
# 1      1    -122.22     37.86                21.0       7099.0
# 2      2    -122.24     37.85                52.0       1467.0
# 3      3    -122.25     37.85                52.0       1274.0
# 6      6    -122.25     37.84                52.0       2535.0
#
#    total_bedrooms  population  households  median_income  median_house_value  \
# 0           129.0       322.0       126.0         8.3252            452600.0
# 1          1106.0      2401.0      1138.0         8.3014            358500.0
# 2           190.0       496.0       177.0         7.2574            352100.0
# 3           235.0       558.0       219.0         5.6431            341300.0
# 6           489.0      1094.0       514.0         3.6591            299200.0
#
#   ocean_proximity
# 0        NEAR BAY
# 1        NEAR BAY
# 2        NEAR BAY
# 3        NEAR BAY
# 6        NEAR BAY

# %%
test_set.head()
# Out:
#     index  longitude  latitude  housing_median_age  total_rooms  \
# 4       4    -122.25     37.85                52.0       1627.0
# 5       5    -122.25     37.85                52.0        919.0
# 11     11    -122.26     37.85                52.0       3503.0
# 20     20    -122.27     37.85                40.0        751.0
# 23     23    -122.27     37.84                52.0       1688.0
#
#     total_bedrooms  population  households  median_income  median_house_value  \
# 4            280.0       565.0       259.0         3.8462            342200.0
# 5            213.0       413.0       193.0         4.0368            269700.0
# 11           752.0      1504.0       734.0         3.2705            241800.0
# 20           184.0       409.0       166.0         1.3578            147500.0
# 23           337.0       853.0       325.0         2.1806             99700.0
#
#    ocean_proximity
# 4         NEAR BAY
# 5         NEAR BAY
# 11        NEAR BAY
# 20        NEAR BAY
# ...

# %%
housing_with_id["id"] = housing["longitude"] * 1000 + housing["latitude"]
train_set, test_set = split_train_test_by_id(housing_with_id, 0.2, "id")

# %%
train_set.head()
# Out:
#    index  longitude  latitude  housing_median_age  total_rooms  \
# 0      0    -122.23     37.88                41.0        880.0
# 1      1    -122.22     37.86                21.0       7099.0
# 2      2    -122.24     37.85                52.0       1467.0
# 3      3    -122.25     37.85                52.0       1274.0
# 4      4    -122.25     37.85                52.0       1627.0
#
#    total_bedrooms  population  households  median_income  median_house_value  \
# 0           129.0       322.0       126.0         8.3252            452600.0
# 1          1106.0      2401.0      1138.0         8.3014            358500.0
# 2           190.0       496.0       177.0         7.2574            352100.0
# 3           235.0       558.0       219.0         5.6431            341300.0
# 4           280.0       565.0       259.0         3.8462            342200.0
#
#   ocean_proximity         id
# 0        NEAR BAY -122192.12
# 1        NEAR BAY -122182.14
# 2        NEAR BAY -122202.15
# ...

# %%
test_set.head()
# Out:
#     index  longitude  latitude  housing_median_age  total_rooms  \
# 8       8    -122.26     37.84                42.0       2555.0
# 10     10    -122.26     37.85                52.0       2202.0
# 11     11    -122.26     37.85                52.0       3503.0
# 12     12    -122.26     37.85                52.0       2491.0
# 13     13    -122.26     37.84                52.0        696.0
#
#     total_bedrooms  population  households  median_income  median_house_value  \
# 8            665.0      1206.0       595.0         2.0804            226700.0
# 10           434.0       910.0       402.0         3.2031            281500.0
# 11           752.0      1504.0       734.0         3.2705            241800.0
# 12           474.0      1098.0       468.0         3.0750            213500.0
# 13           191.0       345.0       174.0         2.6736            191300.0
#
#    ocean_proximity         id
# 8         NEAR BAY -122222.16
# 10        NEAR BAY -122222.15
# ...

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(housing,test_size=0.2, random_state=42)
#atenção para a amostragem estratificada: divisão homogênea para maior representatividade
#evitar viés de amostragem para não ocorrer pesquisas tendenciosas

# %%
#Realizando estratificação da amostragem limitando número de categorias de renda
housing["income_cat"] = np.ceil(housing["median_income"] / 1.5)
#Arredondando para obter categorias discretas

#Mesclando categorias maiores que 5 na categoria 5
housing["income_cat"].where(housing["income_cat"] < 5, 5.0, inplace=True)
#Maior parte da renda se concentra na faixa 20k a 50k US$

# %%
#Exibindo a nova categoria de renda
housing.hist(bins=50, figsize=(35,30))
plt.show()

# %%
from sklearn.model_selection import StratifiedShuffleSplit

split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_index, test_index in split.split(housing, housing["income_cat"]):
    strat_train_set = housing.loc[train_index]
    strat_test_set = housing.loc[test_index]

# %%
strat_test_set["income_cat"].value_counts() / len(strat_test_set)
#proporção de quantidade por categoria em relação ao conjunto de testes
# Out:
# income_cat
# 3.0    0.350533
# 2.0    0.318798
# 4.0    0.176357
# 5.0    0.114341
# 1.0    0.039971
# Name: count, dtype: float64

# %%
overall = pd.concat([strat_train_set, strat_test_set], axis=0)
overall["income_cat"].value_counts() / len(overall)
#proporção de quantidade por categoria em relação a todo o conjunto estratificado completo
# Out:
# income_cat
# 3.0    0.350581
# 2.0    0.318847
# 4.0    0.176308
# 5.0    0.114438
# 1.0    0.039826
# Name: count, dtype: float64

# %%
for set_ in (strat_train_set, strat_test_set):
    set_.drop("income_cat", axis=1, inplace=True)

# %%
#cópia do conjunto de treinamento para exploração dos dados
explore_housing = strat_train_set.copy()
#conjunto de treinamento permanecerá inalterado

# %%
#Fica igual a california :O
explore_housing.plot(kind="scatter", x="longitude", y="latitude", alpha=0.1)
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
#Visualização geográfica mais detalhada

explore_housing.plot(kind="scatter", x="longitude", y="latitude", alpha=0.4,
                     s=explore_housing["population"]/100, label="population", figsize=(10,7),
                     c="median_house_value", cmap=plt.get_cmap("jet"), colorbar=True,)
plt.legend()

# %%
from sklearn.preprocessing import LabelEncoder

#codificando atributos categóricos para valores numéricos
label_encoder = LabelEncoder()
explore_housing["ocean_proximity"] = label_encoder.fit_transform(explore_housing["ocean_proximity"])

#matriz de correlação facilmente obtida (poucos dados de amostragem)
corr_matrix = explore_housing.corr()

# %%
#correlações com o atributo median_house_value
corr_matrix["median_house_value"].sort_values(ascending=False)
#Mede apenas correlaçõe lineares!!!

#coeficiente de correlação varia de -1 a 1
#Próximo de 1: forte correlação positiva
#Próximo de -1: forte correlação negativa
#Próximo de 0: Inexistência de correlação
# Out:
# median_house_value    1.000000
# median_income         0.687151
# total_rooms           0.135140
# housing_median_age    0.114146
# ocean_proximity       0.076936
# households            0.064590
# total_bedrooms        0.047781
# population           -0.026882
# longitude            -0.047466
# latitude             -0.142673
# Name: median_house_value, dtype: float64

# %%
#Matriz de correlação
from pandas.plotting import scatter_matrix

attributes = ["median_house_value", "median_income", "total_rooms", "housing_median_age"]
scatter_matrix(housing[attributes], figsize=(12,8))
#Diagonal principal exibe um histograma da categoria para evitar redundancias de auto-correlação
# Out:
# array([[<Axes: xlabel='median_house_value', ylabel='median_house_value'>,
#         <Axes: xlabel='median_income', ylabel='median_house_value'>,
#         <Axes: xlabel='total_rooms', ylabel='median_house_value'>,
#         <Axes: xlabel='housing_median_age', ylabel='median_house_value'>],
#        [<Axes: xlabel='median_house_value', ylabel='median_income'>,
#         <Axes: xlabel='median_income', ylabel='median_income'>,
#         <Axes: xlabel='total_rooms', ylabel='median_income'>,
#         <Axes: xlabel='housing_median_age', ylabel='median_income'>],
#        [<Axes: xlabel='median_house_value', ylabel='total_rooms'>,
#         <Axes: xlabel='median_income', ylabel='total_rooms'>,
#         <Axes: xlabel='total_rooms', ylabel='total_rooms'>,
#         <Axes: xlabel='housing_median_age', ylabel='total_rooms'>],
#        [<Axes: xlabel='median_house_value', ylabel='housing_median_age'>,
#         <Axes: xlabel='median_income', ylabel='housing_median_age'>,
# ...

# %%
#plotando a correlação de maior relevância
explore_housing.plot(kind="scatter", x="median_income", y="median_house_value", alpha = 0.1)
# Out:
# <Axes: xlabel='median_income', ylabel='median_house_value'>

# %%
#Combinação de atributos
explore_housing["rooms_per_household"] = explore_housing["total_rooms"]/explore_housing["households"]
explore_housing["bedrooms_per_room"] = explore_housing["total_bedrooms"]/explore_housing["total_rooms"]
explore_housing["population_per_household"] = explore_housing["population"]/explore_housing["households"]

#plotando novamente a matriz de correlação
corr_matrix = explore_housing.corr()
corr_matrix["median_house_value"].sort_values(ascending=False)
#habitações com baixa relação quarto/comodo tendem a ser mais caras (correlação negativa)
# Out:
# median_house_value          1.000000
# median_income               0.687151
# rooms_per_household         0.146255
# total_rooms                 0.135140
# housing_median_age          0.114146
# ocean_proximity             0.076936
# households                  0.064590
# total_bedrooms              0.047781
# population_per_household   -0.021991
# population                 -0.026882
# longitude                  -0.047466
# latitude                   -0.142673
# bedrooms_per_room          -0.259952
# Name: median_house_value, dtype: float64

# %%
#preparando os dados para ML

#separadndo previsores e rótulos
housing = strat_train_set.drop("median_house_value", axis=1)
housing_labels = strat_train_set["median_house_value"].copy()
#drop cria uma cópia da original removendo uma coluna específica
#inplace=false não altera a original

# %%
#Preenchendo/Removendo Dados faltantes

#Remove todas as instâncias com valores faltantes
#housing.dropna(subset=["total_bedrooms"])

#Remove o atributo de todas as instâncias
#housing.drop("total_bedrooms", axis=1)

#preenche com o valor médio do atributo
median = housing["total_bedrooms"].median()
housing["total_bedrooms"].fillna(median, inplace=True)

# %%
housing.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12655    -121.46     38.52                29.0       3873.0           797.0
# 15502    -117.23     33.09                 7.0       5320.0           855.0
# 2908     -119.04     35.37                44.0       1618.0           310.0
# 14053    -117.13     32.75                24.0       1877.0           519.0
# 20496    -118.70     34.28                27.0       3536.0           646.0
#
#        population  households  median_income ocean_proximity
# 12655      2237.0       706.0         2.1736          INLAND
# 15502      2015.0       768.0         6.3373      NEAR OCEAN
# 2908        667.0       300.0         2.8750          INLAND
# 14053       898.0       483.0         2.2264      NEAR OCEAN
# 20496      1837.0       580.0         4.4964       <1H OCEAN

# %%
#Reposição de valores faltantes utilizando SciKitLearn
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(missing_values=np.nan,strategy="median")

# %%
#Remoção de atributos não numéricos para o calculo da média
housing_num = housing.drop("ocean_proximity", axis=1)

# %%
#ajustando dados faltantes com a média
imputer.fit(housing_num)
# Out:
# SimpleImputer(strategy='median')

# %%
#valores médios a serem preenchidos nos dados faltantes
imputer.statistics_
# Out:
# array([-118.51   ,   34.26   ,   29.     , 2119.     ,  433.     ,
#        1164.     ,  408.     ,    3.54155])

# %%
#valores médios de cada atributo
housing_num.median().values
# Out:
# array([-118.51   ,   34.26   ,   29.     , 2119.     ,  433.     ,
#        1164.     ,  408.     ,    3.54155])

# %%
#aplicando transformação sobre os dados faltantes
X = imputer.transform(housing_num)
#Array de valores Numpy

#Colocando em um DataFrame
housing_tr = pd.DataFrame(X, columns = housing_num.columns)

# %%
 housing_num.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income'],
#       dtype='object')

# %%
housing_tr.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -121.46     38.52                29.0       3873.0           797.0
# 1    -117.23     33.09                 7.0       5320.0           855.0
# 2    -119.04     35.37                44.0       1618.0           310.0
# 3    -117.13     32.75                24.0       1877.0           519.0
# 4    -118.70     34.28                27.0       3536.0           646.0
#
#    population  households  median_income
# 0      2237.0       706.0         2.1736
# 1      2015.0       768.0         6.3373
# 2       667.0       300.0         2.8750
# 3       898.0       483.0         2.2264
# 4      1837.0       580.0         4.4964

# %%
#Atributos categóricos e Texto
housing_cat = housing["ocean_proximity"]
#Selecionando atributos categóricos

#Mapeamento de valores categóricos para valores numéricos
housing_cat_encoded, housing_categories = housing_cat.factorize()
#factorize() também retorna os indices atribuídos em um formato de array

# %%
#housing_cat_encoded contém os dados categoricos mapeados para valores numéricos
housing_cat_encoded[:10]
# Out:
# array([0, 1, 0, 1, 2, 3, 2, 2, 2, 2], dtype=int64)

# %%
#housing_categories contém os indices atribuidos para os valores não numéricos
housing_categories
# Out:
# Index(['INLAND', 'NEAR OCEAN', '<1H OCEAN', 'NEAR BAY', 'ISLAND'], dtype='object')

# %%
#Criando atributos binários para cada categoria
#O algoritmo de ML pode identificar que duas categorias são semelhantes por suas proximidades numéricas 0: 'INLAND'!= 2:'<1H OCEAN'
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()

#A saída do encoder é uma matriz esparsa
housing_cat_1hot = encoder.fit_transform(housing_cat_encoded.reshape(-1,1))
#fit_transform() espera uma matriz como parâmetro, então é uma remodelagem é feita 

housing_cat_1hot
# Out:
# <16512x5 sparse matrix of type '<class 'numpy.float64'>'
# 	with 16512 stored elements in Compressed Sparse Row format>

# %%
#Customizando transformadores
#Classe de transformador utilizando duck typing para a interface SciKitLearn
from sklearn.base import BaseEstimator, TransformerMixin

#indices dos atributos no conjunto de dados
rooms_ix, bedrooms_ix, population_ix, household_ix = 3, 4, 5, 6

#Classe para fazer transformações dos dados (combinação de atributos personalizada)
class CombinedAttributesAdder(BaseEstimator, TransformerMixin):
    def __init__(self, add_bedrooms_per_room = True):
        self.add_bedrooms_per_room = add_bedrooms_per_room
